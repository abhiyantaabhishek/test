# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiyantaabhishek/test/blob/main/test3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/Test_data.zip

# %%
# !ls Test_data/
# Out:
# Test  Train  Val

# %%
# !mv Test_data/Sample_Submission.csv Sample_Submission.csv
# Out:
# mv: cannot stat 'Test_data/Sample_Submission.csv': No such file or directory

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report,confusion_matrix
import cv2

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ( EarlyStopping, ModelCheckpoint,ReduceLROnPlateau)
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
import tensorflow as tf

# %%
classess = os.listdir("Test_data/Train/")
classess
# Out:
# ['car', 'animal', 'truck', 'human', 'airplane']

# %%
for class_ in classess:
  img_path = os.path.join("Test_data/Train/",class_)
  print( "No of Img Train:", len(os.listdir(img_path)),',',class_)
# Out:
# No of Img Train: 194 , car
# No of Img Train: 194 , animal
# No of Img Train: 194 , truck
# No of Img Train: 194 , human
# No of Img Train: 194 , airplane

# %%
for class_ in classess:
  img_path = os.path.join("Test_data/Val/",class_)
  print( "No of Img Val:", len(os.listdir(img_path)),',',class_)
# Out:
# No of Img Val: 582 , car
# No of Img Val: 582 , animal
# No of Img Val: 582 , truck
# No of Img Val: 582 , human
# No of Img Val: 582 , airplane

# %%
train_images = []
train_labels = []
val_images = []
val_labels = []
test_images = []
test_labels = []
test_images_path =[]
for root, dirs, files in os.walk("Test_data"):
   for name in files:
      full_path = os.path.join(root, name)
      data_type = full_path.split(os.sep)[1]
      img = plt.imread(full_path)
      if(data_type == "Train"):
        label = full_path.split(os.sep)[2]
        train_images.append(img)
        train_labels.append(label)
      elif ( data_type == "Val"):
        label = full_path.split(os.sep)[2]
        val_images.append(img)
        val_labels.append(label)
      else:
        test_images.append(img)
        test_images_path.append(full_path)

# %%
train_images = np.array(train_images)
val_images = np.array(val_images)
test_images = np.array(test_images)
lb = LabelBinarizer()
lb.fit(train_labels)
print(lb.classes_)
train_label_onehot = lb.transform(train_labels)
val_label_onehot = lb.transform(val_labels)
# Out:
# ['airplane' 'animal' 'car' 'human' 'truck']

# %%
print(train_images.shape)
print(val_images.shape)
print(test_images.shape)
assert len(train_images) == len(train_labels)
assert len(val_images) == len(val_labels)
# Out:
# (970, 96, 96)
# (2910, 96, 96)
# (1940, 96, 96)

# %%
hist = plt.hist(train_images.flatten(),bins=100)

# %%
fig, axs = plt.subplots(10, 10,figsize=(15,15))

for i in range(10):
  for j in range(10):
    axs[i,j].imshow(train_images[i*10+j],cmap=plt.cm.gray)
    axs[i,j].set_title(lb.classes_[train_label_onehot[i*10+j].argmax()])
    axs[i,j].axis('off')

# %%
fig, axs = plt.subplots(10, 10,figsize=(15,15))

for i in range(10):
  for j in range(10):
    axs[i,j].imshow(train_images[200+i*10+j],cmap=plt.cm.gray)
    axs[i,j].set_title(lb.classes_[train_label_onehot[200+i*10+j].argmax()])
    axs[i,j].axis('off')

# %%
for ind in range (len(train_images)):
  img = train_images[ind]
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
  opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
  train_images[ind] = opening
for ind in range (len(val_images)):
  img = val_images[ind]
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
  opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
  val_images[ind] = opening
for ind in range (len(test_images)):
  img = test_images[ind]
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
  opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
  test_images[ind] = opening

# %%
fig, axs = plt.subplots(10, 10,figsize=(15,15))

for i in range(10):
  for j in range(10):
    axs[i,j].imshow(train_images[i*10+j],cmap=plt.cm.gray)
    axs[i,j].set_title(lb.classes_[train_label_onehot[i*10+j].argmax()])
    axs[i,j].axis('off')

# %%
fig, axs = plt.subplots(10, 10,figsize=(15,15))

for i in range(10):
  for j in range(10):
    axs[i,j].imshow(train_images[200+i*10+j],cmap=plt.cm.gray)
    axs[i,j].set_title(lb.classes_[train_label_onehot[200+i*10+j].argmax()])
    axs[i,j].axis('off')

# %%
w=25
for ind in range (len(train_images)):
  opening = train_images[ind]
  row_sum = np.arange(len(opening.sum(axis=0)>opening.sum(axis=0).mean()))[opening.sum(axis=0)<opening.sum(axis=0).mean()]
  col_sum = np.arange(len(opening.sum(axis=1)>opening.sum(axis=1).mean()))[opening.sum(axis=1)<opening.sum(axis=1).mean()]
  x_min = row_sum[0]-w if row_sum[0]-w>=0 else 0
  x_max = row_sum[-1] if row_sum[-1]<opening.shape[1] else opening.shape[1]-1 
  y_min = col_sum[0]-w  if col_sum[0]-w>=0 else 0
  y_max = col_sum[-1] if col_sum[-1]<opening.shape[0] else opening.shape[0]-1 
  opening = opening[y_min:y_max,x_min:x_max]  
  opening = cv2.resize(opening, (96, 96),interpolation = cv2.INTER_NEAREST)
  train_images[ind] = opening
for ind in range (len(val_images)):
  opening = val_images[ind]
  row_sum = np.arange(len(opening.sum(axis=0)>opening.sum(axis=0).mean()))[opening.sum(axis=0)<opening.sum(axis=0).mean()]
  col_sum = np.arange(len(opening.sum(axis=1)>opening.sum(axis=1).mean()))[opening.sum(axis=1)<opening.sum(axis=1).mean()]
  x_min = row_sum[0]-w if row_sum[0]-w>=0 else 0
  x_max = row_sum[-1] if row_sum[-1]<opening.shape[1] else opening.shape[1]-1 
  y_min = col_sum[0]-w  if col_sum[0]-w>=0 else 0
  y_max = col_sum[-1] if col_sum[-1]<opening.shape[0] else opening.shape[0]-1 
  opening = opening[y_min:y_max,x_min:x_max]  
  opening = cv2.resize(opening, (96, 96),interpolation = cv2.INTER_NEAREST)  
  val_images[ind] = opening
for ind in range (len(test_images)):
  opening = test_images[ind]
  row_sum = np.arange(len(opening.sum(axis=0)>opening.sum(axis=0).mean()))[opening.sum(axis=0)<opening.sum(axis=0).mean()]
  col_sum = np.arange(len(opening.sum(axis=1)>opening.sum(axis=1).mean()))[opening.sum(axis=1)<opening.sum(axis=1).mean()]
  x_min = row_sum[0]-w if row_sum[0]-w>=0 else 0
  x_max = row_sum[-1] if row_sum[-1]<opening.shape[1] else opening.shape[1]-1 
  y_min = col_sum[0]-w  if col_sum[0]-w>=0 else 0
  y_max = col_sum[-1] if col_sum[-1]<opening.shape[0] else opening.shape[0]-1 
  opening = opening[y_min:y_max,x_min:x_max]  
  opening = cv2.resize(opening, (96, 96),interpolation = cv2.INTER_NEAREST)  
  test_images[ind] = opening

# %%
fig, axs = plt.subplots(10, 10,figsize=(15,15))

for i in range(10):
  for j in range(10):
    axs[i,j].imshow(train_images[i*10+j],cmap=plt.cm.gray)
    axs[i,j].set_title(lb.classes_[train_label_onehot[i*10+j].argmax()])
    axs[i,j].axis('off')

# %%
fig, axs = plt.subplots(10, 10,figsize=(15,15))

for i in range(10):
  for j in range(10):
    axs[i,j].imshow(train_images[200+i*10+j],cmap=plt.cm.gray)
    axs[i,j].set_title(lb.classes_[train_label_onehot[200+i*10+j].argmax()])
    axs[i,j].axis('off')

# %%
train_images_normalised = (train_images-train_images.mean())/train_images.std()
val_images_normalised = (val_images-val_images.mean())/val_images.std()
test_images_normalised = (test_images-test_images.mean())/test_images.std()

# %%
train_images_normalised = (train_images-val_images.mean())/val_images.std()
val_images_normalised = (val_images-val_images.mean())/val_images.std()
test_images_normalised = (test_images-val_images.mean())/val_images.std()

# %%
hist = plt.hist(train_images_normalised.flatten(),bins=100)

# %%
checkpoint = ModelCheckpoint("model_{epoch:02d}",monitor='val_loss',verbose=1,save_best_only=True)
adaptiveLearningRate = ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=5,verbose=1,min_delta=0.0001)
earlyStopping = EarlyStopping(monitor='val_loss',mode='auto',verbose=1,patience=25)
callback_list = [checkpoint,adaptiveLearningRate,earlyStopping]

# %%
def get_model(input_shape,num_of_class,hidden_size1=128,hidden_size2=64,dropout=0.5):
  input = tf.keras.Input(shape=(96,96,1))
  x_skip = input
  x = L.Conv2D(filters=32,kernel_size=(7,7),strides=(1,1), padding = 'same')(input)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x)
  x_skip = L.Conv2D(filters=32,kernel_size=(7,7),strides=(1,1), padding = 'same')(x_skip)
  x = L.Concatenate()([x, x_skip]) 
  x = L.MaxPool2D(pool_size=(2,2))(x)

  
  x_skip = x
  x = L.Conv2D(filters=64,kernel_size=(3,3),strides=(1,1), padding = 'same')(x)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x)
  x_skip = L.Conv2D(filters=64,kernel_size=(3,3),strides=(1,1), padding = 'same')(x_skip)
  x = L.Concatenate()([x, x_skip]) 
  x = L.MaxPool2D(pool_size=(2,2))(x)

  
  x_skip = x
  x = L.Conv2D(filters=128,kernel_size=(3,3),strides=(1,1), padding = 'same')(x)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x) 
  x_skip = L.Conv2D(filters=128,kernel_size=(3,3),strides=(1,1), padding = 'same')(x_skip)
  x = L.Concatenate()([x, x_skip]) 
  x = L.MaxPool2D(pool_size=(2,2))(x)

  x_skip = x
  x = L.Conv2D(filters=256,kernel_size=(3,3),strides=(1,1), padding = 'same')(x)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x) 
  x_skip = L.Conv2D(filters=256,kernel_size=(3,3),strides=(1,1), padding = 'same')(x_skip)
  x = L.Concatenate()([x, x_skip]) 
  x = L.MaxPool2D(pool_size=(2,2))(x)


  x = L.Flatten()(x)
  x = L.Dense(hidden_size1)(x)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x)
  x = L.Dropout(dropout)(x)  
  x = L.Dense(hidden_size2)(x)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x)
  x = L.Dropout(dropout)(x)
  x = L.Dense(num_of_class,activation="softmax")(x)
  model = tf.keras.Model(input,x)
  return model

# %%
def get_model(input_shape,num_of_class,hidden_size1=128,hidden_size2=64,dropout=0.5):
  input = tf.keras.Input(shape=(96,96,1))
  x_skip = input
  x = L.Conv2D(filters=32,kernel_size=(7,7),strides=(1,1), padding = 'same')(input)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x)
  x_skip = L.Conv2D(filters=32,kernel_size=(7,7),strides=(1,1), padding = 'same')(x_skip)
  x = L.Concatenate()([x, x_skip]) 
  x = L.MaxPool2D(pool_size=(2,2))(x)

  
  x_skip = x
  x = L.Conv2D(filters=64,kernel_size=(3,3),strides=(1,1), padding = 'same')(x)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x)
  x_skip = L.Conv2D(filters=64,kernel_size=(3,3),strides=(1,1), padding = 'same')(x_skip)
  x = L.Concatenate()([x, x_skip]) 
  x = L.MaxPool2D(pool_size=(2,2))(x)

  
  x_skip = x
  x = L.Conv2D(filters=128,kernel_size=(3,3),strides=(1,1), padding = 'same')(x)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x) 
  x_skip = L.Conv2D(filters=128,kernel_size=(3,3),strides=(1,1), padding = 'same')(x_skip)
  x = L.Concatenate()([x, x_skip]) 
  x = L.MaxPool2D(pool_size=(2,2))(x)

  x_skip = x
  x = L.Conv2D(filters=256,kernel_size=(3,3),strides=(1,1), padding = 'same')(x)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x) 
  x_skip = L.Conv2D(filters=256,kernel_size=(3,3),strides=(1,1), padding = 'same')(x_skip)
  x = L.Concatenate()([x, x_skip]) 
  x = L.MaxPool2D(pool_size=(2,2))(x)


  x = L.Flatten()(x)
  x = L.Dense(hidden_size1)(x)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x)
  x = L.Dropout(dropout)(x)  
  x = L.Dense(hidden_size2)(x)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x)
  x = L.Dropout(dropout)(x)
  x = L.Dense(num_of_class,activation="softmax")(x)
  model = tf.keras.Model(input,x)
  return model

# %%
input_shape = (96,96,1)
num_of_class = len(lb.classes_)
K.clear_session()
tf.compat.v1.reset_default_graph()
model=get_model(input_shape,num_of_class)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=tf.keras.metrics.CategoricalAccuracy())
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 96, 96, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 96, 96, 32)   1600        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 96, 96, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 96, 96, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 96, 96, 32)   1600        input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 96, 96, 64)   0           activation[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 48, 48, 64)   0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 48, 48, 64)   36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 48, 48, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 48, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 48, 48, 64)   36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 48, 48, 128)  0           activation_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 128)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 24, 24, 128)  147584      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 24, 24, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 24, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 24, 24, 128)  147584      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 24, 24, 256)  0           activation_2[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 256)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 12, 12, 256)  590080      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 12, 12, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 12, 12, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 12, 12, 256)  590080      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 12, 12, 512)  0           activation_3[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 512)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 18432)        0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          2359424     flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128)          512         dense[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           activation_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64)           256         dense_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64)           0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           activation_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 5)            325         dropout_1[0][0]
# ==================================================================================================
# Total params: 3,923,077
# Trainable params: 3,921,733
# Non-trainable params: 1,344
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)

# %%
Augmented_training = ImageDataGenerator(rotation_range=2,
                                        fill_mode='nearest',
                                        horizontal_flip=True,
                                        vertical_flip=True,
                                        width_shift_range=0.001,
                                        height_shift_range=0.001)

# %%
BATCH_SIZE = 64
EPOCHS = 50
model.fit(
    Augmented_training.flow(np.expand_dims(val_images_normalised,3),val_label_onehot,batch_size=BATCH_SIZE),
    steps_per_epoch = len(np.expand_dims(val_images_normalised,3))//BATCH_SIZE,
    validation_data = (train_images_normalised,train_label_onehot),
    validation_steps=len(train_images_normalised)//BATCH_SIZE,
    epochs = EPOCHS,
    callbacks = callback_list
)
# Out:
# Epoch 1/50
# 45/45 [==============================] - 12s 175ms/step - loss: 1.7377 - categorical_accuracy: 0.3264 - val_loss: 1.6817 - val_categorical_accuracy: 0.2041
#
# Epoch 00001: val_loss improved from inf to 1.68175, saving model to model_01
# INFO:tensorflow:Assets written to: model_01/assets
# Epoch 2/50
# 45/45 [==============================] - 7s 144ms/step - loss: 1.3817 - categorical_accuracy: 0.4283 - val_loss: 2.2523 - val_categorical_accuracy: 0.2000
#
# Epoch 00002: val_loss did not improve from 1.68175
# Epoch 3/50
# 45/45 [==============================] - 6s 142ms/step - loss: 1.1657 - categorical_accuracy: 0.5281 - val_loss: 2.8348 - val_categorical_accuracy: 0.2000
#
# Epoch 00003: val_loss did not improve from 1.68175
# Epoch 4/50
# 45/45 [==============================] - 6s 142ms/step - loss: 1.0167 - categorical_accuracy: 0.5966 - val_loss: 3.3791 - val_categorical_accuracy: 0.2000
#
# Epoch 00004: val_loss did not improve from 1.68175
# Epoch 5/50
# 45/45 [==============================] - 6s 143ms/step - loss: 0.9299 - categorical_accuracy: 0.6349 - val_loss: 2.8862 - val_categorical_accuracy: 0.2010
#
# Epoch 00005: val_loss did not improve from 1.68175
# Epoch 6/50
# 45/45 [==============================] - 6s 143ms/step - loss: 0.8371 - categorical_accuracy: 0.6785 - val_loss: 2.8383 - val_categorical_accuracy: 0.2031
#
# Epoch 00006: val_loss did not improve from 1.68175
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 7/50
# 45/45 [==============================] - 6s 143ms/step - loss: 0.7584 - categorical_accuracy: 0.7193 - val_loss: 2.6005 - val_categorical_accuracy: 0.2216
#
# Epoch 00007: val_loss did not improve from 1.68175
# Epoch 8/50
# 45/45 [==============================] - 6s 143ms/step - loss: 0.7254 - categorical_accuracy: 0.7393 - val_loss: 2.2518 - val_categorical_accuracy: 0.2928
#
# Epoch 00008: val_loss did not improve from 1.68175
# Epoch 9/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.7156 - categorical_accuracy: 0.7400 - val_loss: 1.8735 - val_categorical_accuracy: 0.3464
#
# Epoch 00009: val_loss did not improve from 1.68175
# Epoch 10/50
# 45/45 [==============================] - 7s 145ms/step - loss: 0.6871 - categorical_accuracy: 0.7625 - val_loss: 1.6297 - val_categorical_accuracy: 0.4134
#
# Epoch 00010: val_loss improved from 1.68175 to 1.62965, saving model to model_10
# INFO:tensorflow:Assets written to: model_10/assets
# Epoch 11/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.6995 - categorical_accuracy: 0.7481 - val_loss: 1.2508 - val_categorical_accuracy: 0.5155
#
# Epoch 00011: val_loss improved from 1.62965 to 1.25077, saving model to model_11
# INFO:tensorflow:Assets written to: model_11/assets
# Epoch 12/50
# 45/45 [==============================] - 7s 145ms/step - loss: 0.6719 - categorical_accuracy: 0.7698 - val_loss: 1.1393 - val_categorical_accuracy: 0.5598
#
# Epoch 00012: val_loss improved from 1.25077 to 1.13929, saving model to model_12
# INFO:tensorflow:Assets written to: model_12/assets
# Epoch 13/50
# 45/45 [==============================] - 7s 146ms/step - loss: 0.6696 - categorical_accuracy: 0.7755 - val_loss: 1.0414 - val_categorical_accuracy: 0.5990
#
# Epoch 00013: val_loss improved from 1.13929 to 1.04140, saving model to model_13
# INFO:tensorflow:Assets written to: model_13/assets
# Epoch 14/50
# 45/45 [==============================] - 7s 145ms/step - loss: 0.6453 - categorical_accuracy: 0.7818 - val_loss: 0.9652 - val_categorical_accuracy: 0.6124
#
# Epoch 00014: val_loss improved from 1.04140 to 0.96517, saving model to model_14
# INFO:tensorflow:Assets written to: model_14/assets
# Epoch 15/50
# 45/45 [==============================] - 7s 145ms/step - loss: 0.6322 - categorical_accuracy: 0.7730 - val_loss: 0.9363 - val_categorical_accuracy: 0.6351
#
# Epoch 00015: val_loss improved from 0.96517 to 0.93627, saving model to model_15
# INFO:tensorflow:Assets written to: model_15/assets
# Epoch 16/50
# 45/45 [==============================] - 7s 146ms/step - loss: 0.6182 - categorical_accuracy: 0.7987 - val_loss: 0.9173 - val_categorical_accuracy: 0.6361
#
# Epoch 00016: val_loss improved from 0.93627 to 0.91735, saving model to model_16
# INFO:tensorflow:Assets written to: model_16/assets
# Epoch 17/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.6090 - categorical_accuracy: 0.8029 - val_loss: 0.9195 - val_categorical_accuracy: 0.6464
#
# Epoch 00017: val_loss did not improve from 0.91735
# Epoch 18/50
# 45/45 [==============================] - 6s 143ms/step - loss: 0.5891 - categorical_accuracy: 0.8166 - val_loss: 0.9090 - val_categorical_accuracy: 0.6567
#
# Epoch 00018: val_loss improved from 0.91735 to 0.90897, saving model to model_18
# INFO:tensorflow:Assets written to: model_18/assets
# Epoch 19/50
# 45/45 [==============================] - 7s 146ms/step - loss: 0.5778 - categorical_accuracy: 0.8166 - val_loss: 0.8985 - val_categorical_accuracy: 0.6629
#
# Epoch 00019: val_loss improved from 0.90897 to 0.89853, saving model to model_19
# INFO:tensorflow:Assets written to: model_19/assets
# Epoch 20/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.5850 - categorical_accuracy: 0.8141 - val_loss: 0.8987 - val_categorical_accuracy: 0.6557
#
# Epoch 00020: val_loss did not improve from 0.89853
# Epoch 21/50
# 45/45 [==============================] - 6s 143ms/step - loss: 0.5754 - categorical_accuracy: 0.8194 - val_loss: 0.9321 - val_categorical_accuracy: 0.6515
#
# Epoch 00021: val_loss did not improve from 0.89853
# Epoch 22/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.5458 - categorical_accuracy: 0.8370 - val_loss: 0.9028 - val_categorical_accuracy: 0.6670
#
# Epoch 00022: val_loss did not improve from 0.89853
# Epoch 23/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.5396 - categorical_accuracy: 0.8398 - val_loss: 0.8949 - val_categorical_accuracy: 0.6701
#
# Epoch 00023: val_loss improved from 0.89853 to 0.89489, saving model to model_23
# INFO:tensorflow:Assets written to: model_23/assets
# Epoch 24/50
# 45/45 [==============================] - 7s 145ms/step - loss: 0.5430 - categorical_accuracy: 0.8349 - val_loss: 0.8938 - val_categorical_accuracy: 0.6608
#
# Epoch 00024: val_loss improved from 0.89489 to 0.89383, saving model to model_24
# INFO:tensorflow:Assets written to: model_24/assets
# Epoch 25/50
# 45/45 [==============================] - 7s 145ms/step - loss: 0.5205 - categorical_accuracy: 0.8403 - val_loss: 0.8721 - val_categorical_accuracy: 0.6629
#
# Epoch 00025: val_loss improved from 0.89383 to 0.87211, saving model to model_25
# INFO:tensorflow:Assets written to: model_25/assets
# Epoch 26/50
# 45/45 [==============================] - 6s 143ms/step - loss: 0.5225 - categorical_accuracy: 0.8486 - val_loss: 0.8532 - val_categorical_accuracy: 0.6773
#
# Epoch 00026: val_loss improved from 0.87211 to 0.85320, saving model to model_26
# INFO:tensorflow:Assets written to: model_26/assets
# Epoch 27/50
# 45/45 [==============================] - 7s 145ms/step - loss: 0.5114 - categorical_accuracy: 0.8542 - val_loss: 0.8618 - val_categorical_accuracy: 0.6722
#
# Epoch 00027: val_loss did not improve from 0.85320
# Epoch 28/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.5218 - categorical_accuracy: 0.8454 - val_loss: 0.8776 - val_categorical_accuracy: 0.6763
#
# Epoch 00028: val_loss did not improve from 0.85320
# Epoch 29/50
# 45/45 [==============================] - 6s 143ms/step - loss: 0.5049 - categorical_accuracy: 0.8454 - val_loss: 0.8751 - val_categorical_accuracy: 0.6814
#
# Epoch 00029: val_loss did not improve from 0.85320
# Epoch 30/50
# 45/45 [==============================] - 6s 143ms/step - loss: 0.4768 - categorical_accuracy: 0.8623 - val_loss: 0.8528 - val_categorical_accuracy: 0.6845
#
# Epoch 00030: val_loss improved from 0.85320 to 0.85278, saving model to model_30
# INFO:tensorflow:Assets written to: model_30/assets
# Epoch 31/50
# 45/45 [==============================] - 7s 143ms/step - loss: 0.4810 - categorical_accuracy: 0.8616 - val_loss: 0.8738 - val_categorical_accuracy: 0.6876
#
# Epoch 00031: val_loss did not improve from 0.85278
# Epoch 32/50
# 45/45 [==============================] - 6s 143ms/step - loss: 0.4643 - categorical_accuracy: 0.8672 - val_loss: 0.8570 - val_categorical_accuracy: 0.6763
#
# Epoch 00032: val_loss did not improve from 0.85278
# Epoch 33/50
# 45/45 [==============================] - 6s 143ms/step - loss: 0.4554 - categorical_accuracy: 0.8802 - val_loss: 0.8731 - val_categorical_accuracy: 0.6825
#
# Epoch 00033: val_loss did not improve from 0.85278
# Epoch 34/50
# 45/45 [==============================] - 6s 143ms/step - loss: 0.4590 - categorical_accuracy: 0.8717 - val_loss: 0.8953 - val_categorical_accuracy: 0.6804
#
# Epoch 00034: val_loss did not improve from 0.85278
# Epoch 35/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.4421 - categorical_accuracy: 0.8795 - val_loss: 0.8764 - val_categorical_accuracy: 0.6794
#
# Epoch 00035: val_loss did not improve from 0.85278
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 36/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.4659 - categorical_accuracy: 0.8675 - val_loss: 0.8758 - val_categorical_accuracy: 0.6804
#
# Epoch 00036: val_loss did not improve from 0.85278
# Epoch 37/50
# 45/45 [==============================] - 7s 145ms/step - loss: 0.4476 - categorical_accuracy: 0.8812 - val_loss: 0.8795 - val_categorical_accuracy: 0.6794
#
# Epoch 00037: val_loss did not improve from 0.85278
# Epoch 38/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.4532 - categorical_accuracy: 0.8826 - val_loss: 0.8795 - val_categorical_accuracy: 0.6804
#
# Epoch 00038: val_loss did not improve from 0.85278
# Epoch 39/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.4313 - categorical_accuracy: 0.8876 - val_loss: 0.8764 - val_categorical_accuracy: 0.6784
#
# Epoch 00039: val_loss did not improve from 0.85278
# Epoch 40/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.4314 - categorical_accuracy: 0.8893 - val_loss: 0.8704 - val_categorical_accuracy: 0.6814
#
# Epoch 00040: val_loss did not improve from 0.85278
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 41/50
# 45/45 [==============================] - 7s 145ms/step - loss: 0.4406 - categorical_accuracy: 0.8823 - val_loss: 0.8711 - val_categorical_accuracy: 0.6804
#
# Epoch 00041: val_loss did not improve from 0.85278
# Epoch 42/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.4467 - categorical_accuracy: 0.8746 - val_loss: 0.8711 - val_categorical_accuracy: 0.6804
#
# Epoch 00042: val_loss did not improve from 0.85278
# Epoch 43/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.4592 - categorical_accuracy: 0.8693 - val_loss: 0.8717 - val_categorical_accuracy: 0.6814
#
# Epoch 00043: val_loss did not improve from 0.85278
# Epoch 44/50
# 45/45 [==============================] - 7s 145ms/step - loss: 0.4415 - categorical_accuracy: 0.8861 - val_loss: 0.8717 - val_categorical_accuracy: 0.6845
#
# Epoch 00044: val_loss did not improve from 0.85278
# Epoch 45/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.4430 - categorical_accuracy: 0.8753 - val_loss: 0.8720 - val_categorical_accuracy: 0.6845
#
# Epoch 00045: val_loss did not improve from 0.85278
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# Epoch 46/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.4384 - categorical_accuracy: 0.8833 - val_loss: 0.8733 - val_categorical_accuracy: 0.6814
#
# Epoch 00046: val_loss did not improve from 0.85278
# Epoch 47/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.4333 - categorical_accuracy: 0.8813 - val_loss: 0.8724 - val_categorical_accuracy: 0.6835
#
# Epoch 00047: val_loss did not improve from 0.85278
# Epoch 48/50
# 45/45 [==============================] - 6s 143ms/step - loss: 0.4247 - categorical_accuracy: 0.8932 - val_loss: 0.8711 - val_categorical_accuracy: 0.6835
#
# Epoch 00048: val_loss did not improve from 0.85278
# Epoch 49/50
# 45/45 [==============================] - 7s 144ms/step - loss: 0.4393 - categorical_accuracy: 0.8812 - val_loss: 0.8725 - val_categorical_accuracy: 0.6814
#
# Epoch 00049: val_loss did not improve from 0.85278
# Epoch 50/50
# 45/45 [==============================] - 6s 143ms/step - loss: 0.4331 - categorical_accuracy: 0.8879 - val_loss: 0.8740 - val_categorical_accuracy: 0.6825
#
# Epoch 00050: val_loss did not improve from 0.85278
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.

# %%
model.history.history.keys()
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %%
fig=plt.figure()
plt.plot(model.history.history["loss"],label="loss")
plt.plot(model.history.history["val_loss"],label="val_loss")
plt.title("loss vs val_loss")
plt.show()

# %%
prediction = model.predict(val_images_normalised)
print("Train classification report")
print(classification_report(val_label_onehot.argmax(axis=1),prediction.argmax(axis=1),target_names=lb.classes_))
# Out:
# Train classification report
#               precision    recall  f1-score   support
#
#     airplane       0.98      1.00      0.99       582
#       animal       0.99      0.98      0.99       582
#          car       0.96      0.96      0.96       582
#        human       0.99      0.99      0.99       582
#        truck       0.97      0.96      0.96       582
#
#     accuracy                           0.98      2910
#    macro avg       0.98      0.98      0.98      2910
# weighted avg       0.98      0.98      0.98      2910

# %%
prediction = model.predict(train_images_normalised)
print("Val classification report")
print(classification_report(train_label_onehot.argmax(axis=1),prediction.argmax(axis=1),target_names=lb.classes_))
# Out:
# Val classification report
#               precision    recall  f1-score   support
#
#     airplane       0.62      0.77      0.69       194
#       animal       0.79      0.36      0.49       194
#          car       0.73      0.61      0.66       194
#        human       0.73      0.79      0.76       194
#        truck       0.64      0.88      0.74       194
#
#     accuracy                           0.68       970
#    macro avg       0.70      0.68      0.67       970
# weighted avg       0.70      0.68      0.67       970

# %%
prediction = model.predict(test_images_normalised)

# %%
fig, axs = plt.subplots(10, 10,figsize=(15,15))
for i in range(10):
  for j in range(10):
    axs[i,j].imshow(test_images[i*10+j],cmap=plt.cm.gray)
    axs[i,j].set_title(lb.classes_[prediction[i*10+j].argmax()])
    axs[i,j].axis('off')

# %%
import pandas as pd

# %%
data = []
for i,path in enumerate(test_images_path):
  data.append([path.split(os.sep)[-1],lb.classes_[prediction[i].argmax()]])

# %%
df = pd.DataFrame(data=data,columns=['Image_Name','Label'])

# %%
df.head1()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-2e906be7954d> in <module>()
# ----> 1 df.head1()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'head1'

# %%
df.to_csv("Submission1.csv")

# %%
#drive.flush_and_unmount()
