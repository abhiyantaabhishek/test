# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiyantaabhishek/test/blob/main/test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!unzip /content/drive/MyDrive/Test_data.zip

# %%
# !ls Test_data/
# Out:
# Test  Train  Val

# %%
# !mv Test_data/Sample_Submission.csv Sample_Submission.csv
# Out:
# mv: cannot stat 'Test_data/Sample_Submission.csv': No such file or directory

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report,confusion_matrix
import cv2

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ( EarlyStopping, ModelCheckpoint,ReduceLROnPlateau)
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
import tensorflow as tf

# %%
classess = os.listdir("Test_data/Train/")
classess
# Out:
# ['car', 'animal', 'truck', 'human', 'airplane']

# %%
for class_ in classess:
  img_path = os.path.join("Test_data/Train/",class_)
  print( "No of Img Train:", len(os.listdir(img_path)),',',class_)
# Out:
# No of Img Train: 194 , car
# No of Img Train: 194 , animal
# No of Img Train: 194 , truck
# No of Img Train: 194 , human
# No of Img Train: 194 , airplane

# %%
for class_ in classess:
  img_path = os.path.join("Test_data/Val/",class_)
  print( "No of Img Val:", len(os.listdir(img_path)),',',class_)
# Out:
# No of Img Val: 582 , car
# No of Img Val: 582 , animal
# No of Img Val: 582 , truck
# No of Img Val: 582 , human
# No of Img Val: 582 , airplane

# %%
train_images = []
train_labels = []
val_images = []
val_labels = []
test_images = []
test_labels = []
test_images_path =[]
for root, dirs, files in os.walk("Test_data"):
   for name in files:
      full_path = os.path.join(root, name)
      data_type = full_path.split(os.sep)[1]
      img = plt.imread(full_path)
      if(data_type == "Train"):
        label = full_path.split(os.sep)[2]
        train_images.append(img)
        train_labels.append(label)
      elif ( data_type == "Val"):
        label = full_path.split(os.sep)[2]
        val_images.append(img)
        val_labels.append(label)
      else:
        test_images.append(img)
        test_images_path.append(full_path)

# %%
train_images = np.array(train_images)
val_images = np.array(val_images)
test_images = np.array(test_images)
lb = LabelBinarizer()
lb.fit(train_labels)
print(lb.classes_)
train_label_onehot = lb.transform(train_labels)
val_label_onehot = lb.transform(val_labels)
# Out:
# ['airplane' 'animal' 'car' 'human' 'truck']

# %%
print(train_images.shape)
print(val_images.shape)
print(test_images.shape)
assert len(train_images) == len(train_labels)
assert len(val_images) == len(val_labels)
# Out:
# (970, 96, 96)
# (2910, 96, 96)
# (1940, 96, 96)

# %%
hist = plt.hist(train_images.flatten(),bins=100)

# %%
fig, axs = plt.subplots(10, 10,figsize=(15,15))

for i in range(10):
  for j in range(10):
    axs[i,j].imshow(train_images[i*10+j],cmap=plt.cm.gray)
    axs[i,j].set_title(lb.classes_[train_label_onehot[i*10+j].argmax()])
    axs[i,j].axis('off')

# %%
fig, axs = plt.subplots(10, 10,figsize=(15,15))

for i in range(10):
  for j in range(10):
    axs[i,j].imshow(train_images[200+i*10+j],cmap=plt.cm.gray)
    axs[i,j].set_title(lb.classes_[train_label_onehot[200+i*10+j].argmax()])
    axs[i,j].axis('off')

# %%
for ind in range (len(train_images)):
  img = train_images[ind]
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
  opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
  train_images[ind] = opening
for ind in range (len(val_images)):
  img = val_images[ind]
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
  opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
  val_images[ind] = opening
for ind in range (len(test_images)):
  img = test_images[ind]
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
  opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
  test_images[ind] = opening

# %%
fig, axs = plt.subplots(10, 10,figsize=(15,15))

for i in range(10):
  for j in range(10):
    axs[i,j].imshow(train_images[i*10+j],cmap=plt.cm.gray)
    axs[i,j].set_title(lb.classes_[train_label_onehot[i*10+j].argmax()])
    axs[i,j].axis('off')

# %%
fig, axs = plt.subplots(10, 10,figsize=(15,15))

for i in range(10):
  for j in range(10):
    axs[i,j].imshow(train_images[200+i*10+j],cmap=plt.cm.gray)
    axs[i,j].set_title(lb.classes_[train_label_onehot[200+i*10+j].argmax()])
    axs[i,j].axis('off')

# %%
w=15
for ind in range (len(train_images)):
  opening = train_images[ind]
  row_sum = np.arange(len(opening.sum(axis=0)>opening.sum(axis=0).mean()))[opening.sum(axis=0)<opening.sum(axis=0).mean()]
  col_sum = np.arange(len(opening.sum(axis=1)>opening.sum(axis=1).mean()))[opening.sum(axis=1)<opening.sum(axis=1).mean()]
  x_min = row_sum[0]-w if row_sum[0]-w>=0 else 0
  x_max = row_sum[-1] if row_sum[-1]<opening.shape[1] else opening.shape[1]-1 
  y_min = col_sum[0]-w  if col_sum[0]-w>=0 else 0
  y_max = col_sum[-1] if col_sum[-1]<opening.shape[0] else opening.shape[0]-1 
  opening = opening[y_min:y_max,x_min:x_max]  
  opening = cv2.resize(opening, (96, 96),interpolation = cv2.INTER_NEAREST)
  train_images[ind] = opening
for ind in range (len(val_images)):
  opening = val_images[ind]
  row_sum = np.arange(len(opening.sum(axis=0)>opening.sum(axis=0).mean()))[opening.sum(axis=0)<opening.sum(axis=0).mean()]
  col_sum = np.arange(len(opening.sum(axis=1)>opening.sum(axis=1).mean()))[opening.sum(axis=1)<opening.sum(axis=1).mean()]
  x_min = row_sum[0]-w if row_sum[0]-w>=0 else 0
  x_max = row_sum[-1] if row_sum[-1]<opening.shape[1] else opening.shape[1]-1 
  y_min = col_sum[0]-w  if col_sum[0]-w>=0 else 0
  y_max = col_sum[-1] if col_sum[-1]<opening.shape[0] else opening.shape[0]-1 
  opening = opening[y_min:y_max,x_min:x_max]  
  opening = cv2.resize(opening, (96, 96),interpolation = cv2.INTER_NEAREST)  
  val_images[ind] = opening
for ind in range (len(test_images)):
  opening = test_images[ind]
  row_sum = np.arange(len(opening.sum(axis=0)>opening.sum(axis=0).mean()))[opening.sum(axis=0)<opening.sum(axis=0).mean()]
  col_sum = np.arange(len(opening.sum(axis=1)>opening.sum(axis=1).mean()))[opening.sum(axis=1)<opening.sum(axis=1).mean()]
  x_min = row_sum[0]-w if row_sum[0]-w>=0 else 0
  x_max = row_sum[-1] if row_sum[-1]<opening.shape[1] else opening.shape[1]-1 
  y_min = col_sum[0]-w  if col_sum[0]-w>=0 else 0
  y_max = col_sum[-1] if col_sum[-1]<opening.shape[0] else opening.shape[0]-1 
  opening = opening[y_min:y_max,x_min:x_max]  
  opening = cv2.resize(opening, (96, 96),interpolation = cv2.INTER_NEAREST)  
  test_images[ind] = opening

# %%
fig, axs = plt.subplots(10, 10,figsize=(15,15))

for i in range(10):
  for j in range(10):
    axs[i,j].imshow(train_images[i*10+j],cmap=plt.cm.gray)
    axs[i,j].set_title(lb.classes_[train_label_onehot[i*10+j].argmax()])
    axs[i,j].axis('off')

# %%
fig, axs = plt.subplots(10, 10,figsize=(15,15))

for i in range(10):
  for j in range(10):
    axs[i,j].imshow(train_images[200+i*10+j],cmap=plt.cm.gray)
    axs[i,j].set_title(lb.classes_[train_label_onehot[200+i*10+j].argmax()])
    axs[i,j].axis('off')

# %%
train_images_normalised = (train_images-train_images.mean())/train_images.std()
val_images_normalised = (val_images-val_images.mean())/val_images.std()
test_images_normalised = (test_images-test_images.mean())/test_images.std()

# %%
hist = plt.hist(train_images_normalised.flatten(),bins=100)

# %%
checkpoint = ModelCheckpoint("model_{epoch:02d}",monitor='val_loss',verbose=1,save_best_only=True)
adaptiveLearningRate = ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=5,verbose=1,min_delta=0.0001)
earlyStopping = EarlyStopping(monitor='val_loss',mode='auto',verbose=1,patience=25)
callback_list = [checkpoint,adaptiveLearningRate,earlyStopping]

# %%
def get_model(input_shape,num_of_class,hidden_size=64,dropout=0.5):
  input = tf.keras.Input(shape=(96,96,1))
  x_skip = input
  x = L.Conv2D(filters=32,kernel_size=(7,7),strides=(1,1), padding = 'same')(input)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x)
  x_skip = L.Conv2D(filters=32,kernel_size=(7,7),strides=(1,1), padding = 'same')(x_skip)
  x = L.Concatenate()([x, x_skip]) 
  x = L.MaxPool2D(pool_size=(2,2))(x)

  
  x_skip = x
  x = L.Conv2D(filters=64,kernel_size=(3,3),strides=(1,1), padding = 'same')(x)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x)
  x_skip = L.Conv2D(filters=64,kernel_size=(3,3),strides=(1,1), padding = 'same')(x_skip)
  x = L.Concatenate()([x, x_skip]) 
  x = L.MaxPool2D(pool_size=(2,2))(x)

  
  x_skip = x
  x = L.Conv2D(filters=128,kernel_size=(3,3),strides=(1,1), padding = 'same')(x)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x) 
  x_skip = L.Conv2D(filters=128,kernel_size=(3,3),strides=(1,1), padding = 'same')(x_skip)
  x = L.Concatenate()([x, x_skip]) 
  x = L.MaxPool2D(pool_size=(2,2))(x)

  x_skip = x
  x = L.Conv2D(filters=256,kernel_size=(3,3),strides=(1,1), padding = 'same')(x)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x) 
  x_skip = L.Conv2D(filters=256,kernel_size=(3,3),strides=(1,1), padding = 'same')(x_skip)
  x = L.Concatenate()([x, x_skip]) 
  x = L.MaxPool2D(pool_size=(2,2))(x)


  x = L.Flatten()(x)
  x = L.Dense(hidden_size)(x)
  x = L.BatchNormalization()(x)
  x = L.Activation('relu')(x)
  x = L.Dropout(dropout)(x)
  x = L.Dense(num_of_class,activation="softmax")(x)
  model = tf.keras.Model(input,x)
  return model

# %%
input_shape = (96,96,1)
num_of_class = len(lb.classes_)
K.clear_session()
model=get_model(input_shape,num_of_class)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=tf.keras.metrics.CategoricalAccuracy())
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 96, 96, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 96, 96, 32)   1600        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 96, 96, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 96, 96, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 96, 96, 32)   1600        input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 96, 96, 64)   0           activation[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 48, 48, 64)   0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 48, 48, 64)   36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 48, 48, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 48, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 48, 48, 64)   36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 48, 48, 128)  0           activation_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 128)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 24, 24, 128)  147584      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 24, 24, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 24, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 24, 24, 128)  147584      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 24, 24, 256)  0           activation_2[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 256)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 12, 12, 256)  590080      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 12, 12, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 12, 12, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 12, 12, 256)  590080      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 12, 12, 512)  0           activation_3[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 512)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 18432)        0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           1179712     flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64)           256         dense[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64)           0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           activation_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 5)            325         dropout[0][0]
# ==================================================================================================
# Total params: 2,734,597
# Trainable params: 2,733,509
# Non-trainable params: 1,088
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)

# %%
Augmented_training = ImageDataGenerator(rotation_range=2,
                                        fill_mode='nearest',
                                        horizontal_flip=True,
                                        vertical_flip=True,
                                        width_shift_range=0.001,
                                        height_shift_range=0.001)

# %%
BATCH_SIZE = 32
EPOCHS = 50
model.fit(
    Augmented_training.flow(np.expand_dims(val_images_normalised,3),val_label_onehot,batch_size=BATCH_SIZE),
    steps_per_epoch = len(np.expand_dims(val_images_normalised,3))//BATCH_SIZE,
    validation_data = (train_images_normalised,train_label_onehot),
    validation_steps=len(train_images_normalised)//BATCH_SIZE,
    epochs = EPOCHS,
    callbacks = callback_list
)
# Out:
# Epoch 1/50
# 90/90 [==============================] - 9s 82ms/step - loss: 1.9608 - categorical_accuracy: 0.3033 - val_loss: 1.6104 - val_categorical_accuracy: 0.2351
#
# Epoch 00001: val_loss improved from inf to 1.61036, saving model to model_01
# INFO:tensorflow:Assets written to: model_01/assets
# Epoch 2/50
# 90/90 [==============================] - 7s 79ms/step - loss: 1.5027 - categorical_accuracy: 0.4368 - val_loss: 1.7647 - val_categorical_accuracy: 0.2196
#
# Epoch 00002: val_loss did not improve from 1.61036
# Epoch 3/50
# 90/90 [==============================] - 7s 78ms/step - loss: 1.2725 - categorical_accuracy: 0.5090 - val_loss: 1.7288 - val_categorical_accuracy: 0.2619
#
# Epoch 00003: val_loss did not improve from 1.61036
# Epoch 4/50
# 90/90 [==============================] - 7s 78ms/step - loss: 1.1481 - categorical_accuracy: 0.5462 - val_loss: 1.5437 - val_categorical_accuracy: 0.3732
#
# Epoch 00004: val_loss improved from 1.61036 to 1.54372, saving model to model_04
# INFO:tensorflow:Assets written to: model_04/assets
# Epoch 5/50
# 90/90 [==============================] - 7s 78ms/step - loss: 1.0561 - categorical_accuracy: 0.5945 - val_loss: 1.3767 - val_categorical_accuracy: 0.4629
#
# Epoch 00005: val_loss improved from 1.54372 to 1.37669, saving model to model_05
# INFO:tensorflow:Assets written to: model_05/assets
# Epoch 6/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.9646 - categorical_accuracy: 0.6345 - val_loss: 1.4038 - val_categorical_accuracy: 0.4598
#
# Epoch 00006: val_loss did not improve from 1.37669
# Epoch 7/50
# 90/90 [==============================] - 7s 79ms/step - loss: 0.8953 - categorical_accuracy: 0.6675 - val_loss: 1.3623 - val_categorical_accuracy: 0.4598
#
# Epoch 00007: val_loss improved from 1.37669 to 1.36234, saving model to model_07
# INFO:tensorflow:Assets written to: model_07/assets
# Epoch 8/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.8257 - categorical_accuracy: 0.6849 - val_loss: 1.4092 - val_categorical_accuracy: 0.4546
#
# Epoch 00008: val_loss did not improve from 1.36234
# Epoch 9/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.7645 - categorical_accuracy: 0.7259 - val_loss: 1.3005 - val_categorical_accuracy: 0.4814
#
# Epoch 00009: val_loss improved from 1.36234 to 1.30053, saving model to model_09
# INFO:tensorflow:Assets written to: model_09/assets
# Epoch 10/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.7299 - categorical_accuracy: 0.7314 - val_loss: 1.4938 - val_categorical_accuracy: 0.4423
#
# Epoch 00010: val_loss did not improve from 1.30053
# Epoch 11/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.6774 - categorical_accuracy: 0.7585 - val_loss: 1.4794 - val_categorical_accuracy: 0.4629
#
# Epoch 00011: val_loss did not improve from 1.30053
# Epoch 12/50
# 90/90 [==============================] - 7s 79ms/step - loss: 0.6872 - categorical_accuracy: 0.7557 - val_loss: 1.2588 - val_categorical_accuracy: 0.5062
#
# Epoch 00012: val_loss improved from 1.30053 to 1.25879, saving model to model_12
# INFO:tensorflow:Assets written to: model_12/assets
# Epoch 13/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.6453 - categorical_accuracy: 0.7724 - val_loss: 1.2552 - val_categorical_accuracy: 0.5186
#
# Epoch 00013: val_loss improved from 1.25879 to 1.25516, saving model to model_13
# INFO:tensorflow:Assets written to: model_13/assets
# Epoch 14/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.6126 - categorical_accuracy: 0.7957 - val_loss: 1.1890 - val_categorical_accuracy: 0.5216
#
# Epoch 00014: val_loss improved from 1.25516 to 1.18895, saving model to model_14
# INFO:tensorflow:Assets written to: model_14/assets
# Epoch 15/50
# 90/90 [==============================] - 7s 79ms/step - loss: 0.5743 - categorical_accuracy: 0.8245 - val_loss: 1.3799 - val_categorical_accuracy: 0.4701
#
# Epoch 00015: val_loss did not improve from 1.18895
# Epoch 16/50
# 90/90 [==============================] - 7s 79ms/step - loss: 0.5643 - categorical_accuracy: 0.8155 - val_loss: 1.2153 - val_categorical_accuracy: 0.5299
#
# Epoch 00016: val_loss did not improve from 1.18895
# Epoch 17/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.5338 - categorical_accuracy: 0.8218 - val_loss: 1.2715 - val_categorical_accuracy: 0.5041
#
# Epoch 00017: val_loss did not improve from 1.18895
# Epoch 18/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.5301 - categorical_accuracy: 0.8315 - val_loss: 1.1888 - val_categorical_accuracy: 0.5495
#
# Epoch 00018: val_loss improved from 1.18895 to 1.18876, saving model to model_18
# INFO:tensorflow:Assets written to: model_18/assets
# Epoch 19/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.5027 - categorical_accuracy: 0.8485 - val_loss: 1.3278 - val_categorical_accuracy: 0.4876
#
# Epoch 00019: val_loss did not improve from 1.18876
# Epoch 20/50
# 90/90 [==============================] - 7s 79ms/step - loss: 0.4831 - categorical_accuracy: 0.8593 - val_loss: 1.3139 - val_categorical_accuracy: 0.5247
#
# Epoch 00020: val_loss did not improve from 1.18876
# Epoch 21/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.4600 - categorical_accuracy: 0.8648 - val_loss: 1.2343 - val_categorical_accuracy: 0.5464
#
# Epoch 00021: val_loss did not improve from 1.18876
# Epoch 22/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.4637 - categorical_accuracy: 0.8697 - val_loss: 1.1593 - val_categorical_accuracy: 0.5670
#
# Epoch 00022: val_loss improved from 1.18876 to 1.15932, saving model to model_22
# INFO:tensorflow:Assets written to: model_22/assets
# Epoch 23/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.4365 - categorical_accuracy: 0.8780 - val_loss: 1.2045 - val_categorical_accuracy: 0.5485
#
# Epoch 00023: val_loss did not improve from 1.15932
# Epoch 24/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.4273 - categorical_accuracy: 0.8815 - val_loss: 1.3345 - val_categorical_accuracy: 0.5216
#
# Epoch 00024: val_loss did not improve from 1.15932
# Epoch 25/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.4160 - categorical_accuracy: 0.8791 - val_loss: 1.0453 - val_categorical_accuracy: 0.6072
#
# Epoch 00025: val_loss improved from 1.15932 to 1.04527, saving model to model_25
# INFO:tensorflow:Assets written to: model_25/assets
# Epoch 26/50
# 90/90 [==============================] - 7s 79ms/step - loss: 0.4095 - categorical_accuracy: 0.8888 - val_loss: 1.2498 - val_categorical_accuracy: 0.5567
#
# Epoch 00026: val_loss did not improve from 1.04527
# Epoch 27/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.3766 - categorical_accuracy: 0.9093 - val_loss: 1.1337 - val_categorical_accuracy: 0.5897
#
# Epoch 00027: val_loss did not improve from 1.04527
# Epoch 28/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.3799 - categorical_accuracy: 0.9044 - val_loss: 1.1211 - val_categorical_accuracy: 0.5907
#
# Epoch 00028: val_loss did not improve from 1.04527
# Epoch 29/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.3683 - categorical_accuracy: 0.9024 - val_loss: 1.1076 - val_categorical_accuracy: 0.6041
#
# Epoch 00029: val_loss did not improve from 1.04527
# Epoch 30/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.3733 - categorical_accuracy: 0.9072 - val_loss: 0.9786 - val_categorical_accuracy: 0.6320
#
# Epoch 00030: val_loss improved from 1.04527 to 0.97855, saving model to model_30
# INFO:tensorflow:Assets written to: model_30/assets
# Epoch 31/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.3545 - categorical_accuracy: 0.9114 - val_loss: 1.1019 - val_categorical_accuracy: 0.6062
#
# Epoch 00031: val_loss did not improve from 0.97855
# Epoch 32/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.3463 - categorical_accuracy: 0.9173 - val_loss: 1.1108 - val_categorical_accuracy: 0.6072
#
# Epoch 00032: val_loss did not improve from 0.97855
# Epoch 33/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.3280 - categorical_accuracy: 0.9243 - val_loss: 1.0683 - val_categorical_accuracy: 0.6186
#
# Epoch 00033: val_loss did not improve from 0.97855
# Epoch 34/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.3158 - categorical_accuracy: 0.9336 - val_loss: 1.0195 - val_categorical_accuracy: 0.6392
#
# Epoch 00034: val_loss did not improve from 0.97855
# Epoch 35/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.3244 - categorical_accuracy: 0.9288 - val_loss: 1.0791 - val_categorical_accuracy: 0.6124
#
# Epoch 00035: val_loss did not improve from 0.97855
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 36/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2990 - categorical_accuracy: 0.9382 - val_loss: 1.0830 - val_categorical_accuracy: 0.6113
#
# Epoch 00036: val_loss did not improve from 0.97855
# Epoch 37/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2905 - categorical_accuracy: 0.9385 - val_loss: 1.0631 - val_categorical_accuracy: 0.6144
#
# Epoch 00037: val_loss did not improve from 0.97855
# Epoch 38/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2956 - categorical_accuracy: 0.9333 - val_loss: 1.0461 - val_categorical_accuracy: 0.6196
#
# Epoch 00038: val_loss did not improve from 0.97855
# Epoch 39/50
# 90/90 [==============================] - 7s 79ms/step - loss: 0.2913 - categorical_accuracy: 0.9399 - val_loss: 1.0329 - val_categorical_accuracy: 0.6278
#
# Epoch 00039: val_loss did not improve from 0.97855
# Epoch 40/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2937 - categorical_accuracy: 0.9399 - val_loss: 1.0682 - val_categorical_accuracy: 0.6082
#
# Epoch 00040: val_loss did not improve from 0.97855
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 41/50
# 90/90 [==============================] - 7s 79ms/step - loss: 0.2983 - categorical_accuracy: 0.9319 - val_loss: 1.0553 - val_categorical_accuracy: 0.6144
#
# Epoch 00041: val_loss did not improve from 0.97855
# Epoch 42/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2873 - categorical_accuracy: 0.9437 - val_loss: 1.0443 - val_categorical_accuracy: 0.6196
#
# Epoch 00042: val_loss did not improve from 0.97855
# Epoch 43/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2900 - categorical_accuracy: 0.9368 - val_loss: 1.0415 - val_categorical_accuracy: 0.6237
#
# Epoch 00043: val_loss did not improve from 0.97855
# Epoch 44/50
# 90/90 [==============================] - 7s 79ms/step - loss: 0.2888 - categorical_accuracy: 0.9461 - val_loss: 1.0445 - val_categorical_accuracy: 0.6196
#
# Epoch 00044: val_loss did not improve from 0.97855
# Epoch 45/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2870 - categorical_accuracy: 0.9451 - val_loss: 1.0473 - val_categorical_accuracy: 0.6186
#
# Epoch 00045: val_loss did not improve from 0.97855
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# Epoch 46/50
# 90/90 [==============================] - 7s 79ms/step - loss: 0.3059 - categorical_accuracy: 0.9364 - val_loss: 1.0432 - val_categorical_accuracy: 0.6196
#
# Epoch 00046: val_loss did not improve from 0.97855
# Epoch 47/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2833 - categorical_accuracy: 0.9430 - val_loss: 1.0431 - val_categorical_accuracy: 0.6237
#
# Epoch 00047: val_loss did not improve from 0.97855
# Epoch 48/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2859 - categorical_accuracy: 0.9416 - val_loss: 1.0468 - val_categorical_accuracy: 0.6186
#
# Epoch 00048: val_loss did not improve from 0.97855
# Epoch 49/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2969 - categorical_accuracy: 0.9382 - val_loss: 1.0455 - val_categorical_accuracy: 0.6206
#
# Epoch 00049: val_loss did not improve from 0.97855
# Epoch 50/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2987 - categorical_accuracy: 0.9368 - val_loss: 1.0497 - val_categorical_accuracy: 0.6165
#
# Epoch 00050: val_loss did not improve from 0.97855
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.

# %%
fig=plt.figure()
plt.plot(model.history.history["loss"],label="loss")
plt.plot(model.history.history["val_loss"],label="val_loss")
plt.title("loss vs val_loss")
plt.show()

# %%
prediction = model.predict(val_images_normalised)
print("Train classification report")
print(classification_report(val_label_onehot.argmax(axis=1),prediction.argmax(axis=1),target_names=lb.classes_))
# Out:
# Train classification report
#               precision    recall  f1-score   support
#
#     airplane       0.97      1.00      0.99       582
#       animal       1.00      0.98      0.99       582
#          car       0.99      0.98      0.98       582
#        human       0.98      1.00      0.99       582
#        truck       0.99      0.98      0.99       582
#
#     accuracy                           0.99      2910
#    macro avg       0.99      0.99      0.99      2910
# weighted avg       0.99      0.99      0.99      2910

# %%
prediction = model.predict(train_images_normalised)
print("Val classification report")
print(classification_report(train_label_onehot.argmax(axis=1),prediction.argmax(axis=1),target_names=lb.classes_))
# Out:
# Val classification report
#               precision    recall  f1-score   support
#
#     airplane       0.43      0.80      0.56       194
#       animal       0.61      0.47      0.53       194
#          car       0.71      0.50      0.59       194
#        human       0.75      0.59      0.66       194
#        truck       0.82      0.73      0.77       194
#
#     accuracy                           0.62       970
#    macro avg       0.66      0.62      0.62       970
# weighted avg       0.66      0.62      0.62       970

# %%
prediction = model.predict(test_images_normalised)

# %%
fig, axs = plt.subplots(10, 10,figsize=(15,15))
for i in range(10):
  for j in range(10):
    axs[i,j].imshow(test_images[i*10+j],cmap=plt.cm.gray)
    axs[i,j].set_title(lb.classes_[prediction[i*10+j].argmax()])
    axs[i,j].axis('off')

# %%
import pandas as pd

# %%
data = []
for i,path in enumerate(test_images_path):
  data.append([path.split(os.sep)[-1],lb.classes_[prediction[i].argmax()]])

# %%
df = pd.DataFrame(data=data,columns=['Image_Name','Label'])

# %%
df.head1()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-2e906be7954d> in <module>()
# ----> 1 df.head1()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'head1'

# %%
df.to_csv("Submission1.csv")

# %%
#drive.flush_and_unmount()
